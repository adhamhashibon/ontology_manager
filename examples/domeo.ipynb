# %% [markdown]
# # DOMEO 4.0 -
# ## Load the New DOME 4.0 core ontology,
# this is the first step, we need to go through the entier ontologies and consolidate into an eco system
#
# currently:
#
# 1. the ontology is a patch work, no coherency,
# 2. EurosciVoc is not used !
#
#
# ## Tasks:
# 1. load the `~/dev/ontology/dome/Ontology-matters/dome4.0_core.ttl`
#    - Working forlder: `~/dev/ontology/ontology_manager`
# 3.

# %%
from ontology_manager.ontology_utils import OntologyManager
from rdflib import Graph, URIRef, Namespace, Literal, BNode, collection
from rdflib.namespace import SKOS, RDF, RDFS, OWL

# %%
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph, rdflib_to_graphtool
import networkx as nx
import matplotlib.pyplot as plt

# %%
from ontodot.ontodot import vis 
from ontodot.ontodot import OntoVis

# %%
from types import SimpleNamespace
import os

# %%
def printH(s):
    the_line = "=" * (len(s)+1)
    print(f"{s}:\n{the_line}")

# %%
def auto_bind_namespaces(g:Graph, prefixes_copy_paste_string):
    """
    prefixes_copy_paste_string is as the name suggestes a copy paste of the header in attl file with 
    the form: 
    @prefix dcat: <http://www.w3.org/ns/dcat#> .


    i.e, no additional comments... 
    and g is any Graph
    """
    split_to_lines = prefixes_copy_paste_string.strip().split("\n")
    for line in split_to_lines:
        the_parts = line.split()
        if the_parts[0] == "@prefix":
            prefix = the_parts[1].rstrip(":")
            uri = the_parts[2].lstrip("<").rstrip("> .")
            print(f"g.bind({prefix}, {Namespace(uri)})")
            g.bind(prefix, Namespace(uri))

# %%
dome=SimpleNamespace()

# %%
dome.g=Graph(bind_namespaces="rdflib")
dome.ns=Namespace('https://dome40.eu/semantics/dome4.0_core#')
dome.path = "/Users/adham/dev/dome/Ontology-matters/domeo"
dome.file='domeo.ttl'
dome.g.parse(os.path.join(dome.path, dome.file))
# we could add it to mio_manager manually actually, then use it as we want,
# Out:
# <Graph identifier=Nb4575510beea4aa6b5b82e11887f0e35 (<class 'rdflib.graph.Graph'>)>

# %%
binds="""
@dome-core: <https://dome40.eu/semantics/dome4.0_core#> .
@prefix dcat: <http://www.w3.org/ns/dcat#> .
@prefix dcterms: <http://purl.org/dc/terms/> .
@prefix euroscivoc: <http://data.europa.eu/8mn/euroscivoc/> .
@prefix evmpo: <https://emmc.eu/semantics/evmpo/evmpo.ttl#> .
@prefix foaf: <http://xmlns.com/foaf/0.1/> .
@prefix http-meth: <http://www.w3.org/2011/http-methods#> .
@prefix msm: <http://iserve.kmi.open.ac.uk/ns/msm#> .
@prefix owl: <http://www.w3.org/2002/07/owl#> .
@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
@prefix skos: <http://www.w3.org/2004/02/skos/core#> .
@prefix xs: <http://www.w3.org/2001/XMLSchema#> .
"""
auto_bind_namespaces(dome.g, binds)
# Out:
# g.bind(dcat, http://www.w3.org/ns/dcat#)
# g.bind(dcterms, http://purl.org/dc/terms/)
# g.bind(euroscivoc, http://data.europa.eu/8mn/euroscivoc/)
# g.bind(evmpo, https://emmc.eu/semantics/evmpo/evmpo.ttl#)
# g.bind(foaf, http://xmlns.com/foaf/0.1/)
# g.bind(http-meth, http://www.w3.org/2011/http-methods#)
# g.bind(msm, http://iserve.kmi.open.ac.uk/ns/msm#)
# g.bind(owl, http://www.w3.org/2002/07/owl#)
# g.bind(rdf, http://www.w3.org/1999/02/22-rdf-syntax-ns#)
# g.bind(rdfs, http://www.w3.org/2000/01/rdf-schema#)
# g.bind(skos, http://www.w3.org/2004/02/skos/core#)
# g.bind(xs, http://www.w3.org/2001/XMLSchema#)

# %% [markdown]
# # Issue: Unnamed, Blind Nodes!
# There is an issue with many "non standard, non web friendly" constructus inherited from other ontologies that are included.
#
# e.g., all the below terms cannot be used in any suitable technology.

# %%
for s,p,o in dome.g:
    if not isinstance(s, URIRef):
        print (p.n3(dome.g.namespace_manager), o.n3(dome.g.namespace_manager))
# Out:
# owl:hasValue dome-core:CONSUMER
# rdf:rest rdf:nil
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b20
# owl:hasValue dome-core:DATA_PROVIDER
# rdf:first http-meth:PUT
# rdf:type owl:Restriction
# rdf:rest rdf:nil
# rdf:first _:n148d76cf1f714f1ca12023651320e337b35
# rdf:first dome-core:has_operation_type
# rdf:type owl:Restriction
# rdf:rest rdf:nil
# owl:onProperty dome-core:has_oper_has_meth
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b30
# rdf:first http-meth:GET
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b2
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b22
# rdfs:subClassOf _:n148d76cf1f714f1ca12023651320e337b43
# owl:onProperty dome-core:has_oper_has_meth
# rdf:rest rdf:nil
# rdf:type owl:Restriction
# rdf:first http-meth:TRACE
# rdf:first _:n148d76cf1f714f1ca12023651320e337b36
# rdf:type owl:Class
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b24
# rdf:rest rdf:nil
# rdf:first dome-core:offering_subscription
# rdf:first dome-core:offering_one_off_sale
# owl:unionOf _:n148d76cf1f714f1ca12023651320e337b19
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b13
# owl:unionOf _:n148d76cf1f714f1ca12023651320e337b32
# rdf:rest rdf:nil
# rdf:rest rdf:nil
# owl:hasValue http-meth:PUT
# owl:onProperty dome-core:has_oper_has_meth
# rdf:first http-meth:DELETE
# rdf:first dome-core:has_product_catalogue
# owl:hasValue http-meth:POST
# rdf:first dome-core:includes_platform
# rdf:first dome-core:dataset
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b26
# owl:hasValue http-meth:CONNECT
# rdf:first http-meth:HEAD
# rdf:first dome-core:has_operation
# owl:someValuesFrom dome-core:post_or_put_type_service
# rdf:first dome-core:has_product_type
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b14
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b8
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b12
# rdf:rest rdf:nil
# rdf:first http-meth:OPTIONS
# owl:onProperty dome-core:has_oper_has_meth
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b33
# rdf:rest rdf:nil
# rdf:first dome-core:has_entry_for
# rdfs:subClassOf _:n148d76cf1f714f1ca12023651320e337b41
# owl:onProperty dome-core:has_service
# rdf:rest rdf:nil
# owl:hasValue dome-core:INTERACTIVE_APP_PROVIDER
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b11
# owl:someValuesFrom dome-core:get_type_service
# owl:someValuesFrom dome-core:connect_type_service
# rdf:type owl:Restriction
# rdf:first http-meth:CONNECT
# owl:onProperty dome-core:has_platform_type
# rdf:rest rdf:nil
# rdf:first dome-core:UK_ENGLISH
# owl:onProperty dome-core:has_platform_type
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b4
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b6
# rdf:first dome-core:offers_product
# rdf:type owl:Restriction
# rdf:type owl:Restriction
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b15
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b38
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b10
# rdf:first dome-core:US_ENGLISH
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b17
# rdfs:subClassOf _:n148d76cf1f714f1ca12023651320e337b45
# rdf:type owl:Restriction
# owl:onProperty dome-core:has_service
# rdf:first http-meth:PATCH
# owl:hasValue http-meth:GET
# rdf:rest rdf:nil
# rdf:first dome-core:offering_by_usage
# rdf:type owl:Restriction
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b9
# owl:onProperty dome-core:has_platform_type
# rdf:first evmpo:infrastructure
# rdf:first dome-core:has_operation
# rdf:first dome-core:offers_product
# rdf:first dome-core:offering_flat
# rdf:first dome-core:data_service
# owl:onProperty dome-core:has_service
# rdf:first dome-core:product
# rdf:type owl:Restriction
# rdf:type owl:Restriction
# rdf:rest _:n148d76cf1f714f1ca12023651320e337b28
# rdf:first http-meth:POST
# rdf:rest rdf:nil
# rdf:first dome-core:product_type
# rdf:first dome-core:has_http_method
# rdf:type owl:Class
# rdf:first evmpo:information_content_entity

# %% [markdown]
# # Needed Enhancements and consolidations.
# ```
# dome-core:has_service_type
#   a owl:ObjectProperty ;
#   rdfs:comment "Points to the service type (cf. 'action')"^^xs:string ;
#   rdfs:comment "For example: View, Download, etc. "^^xs:string ;
#   rdfs:comment "In DCAT, dct:type is used for this purpose. "^^xs:string ;
#   rdfs:domain dome-core:service ;
#   rdfs:range dome-core:action ;
#   owl:propertyChainAxiom (dome-core:has_operation dome-core:has_operation_type) .
# ```
# The above is one of many examples where constructus are hard to work with, and do not enable proper identification and provenance.

# %% [markdown]
# # ISSUE: Lack of utilisation of EurosciVoc, https://op.europa.eu/en/web/eu-vocabularies/navigation and https://op.europa.eu/en/web/eu-vocabularies/ontologies etc.
#
#
# There is a need to streamline these ontologies.

# %%
vis(dome.g, max_string_length=5) # Standard methods do not work with it!
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 vis(dome.g, max_string_length=5) # Standard methods do not work with it!
#
# File ~/dev/ontology/ontology_manager/ontodot/ontodot.py:66, in vis(g, start_serial_number, max_string_length)
#      63 rdf2dot(g_copy, stream)
#      65 dg = pydotplus.graph_from_dot_data(stream.getvalue())
# ---> 66 png = dg.create_png()
#      68 # Create the "output" folder if it doesn't exist
#      69 os.makedirs(output_folder, exist_ok=True)
#
# File ~/dev/new/osp-core/.env/lib/python3.11/site-packages/pydotplus/graphviz.py:1797, in Dot.__init__.<locals>.<lambda>(f, prog)
#    1792 # Automatically creates all the methods enabling the creation
#    1793 # of output in any of the supported formats.
#    1794 for frmt in self.formats:
#    1795     self.__setattr__(
#    1796         'create_' + frmt,
# -> 1797         lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798     )
#    1799     f = self.__dict__['create_' + frmt]
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#
# File ~/dev/new/osp-core/.env/lib/python3.11/site-packages/pydotplus/graphviz.py:2030, in Dot.create(self, prog, format)
#    2027 status = p.wait()
#    2029 if status != 0:
# -> 2030     raise InvocationException(
#    2031         'Program terminated with status: %d. stderr follows: %s' % (
#    2032             status, stderr_output))
#    2033 elif stderr_output:
#    2034     print(stderr_output)
#
# InvocationException: Program terminated with status: 1. stderr follows: Error: syntax error in line 1
# ... <B></B> ...

# %%
print(dome.g.serialize())
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dome-core: <https://dome40.eu/semantics/dome4.0_core#> .
# @prefix evmpo: <https://emmc.eu/semantics/evmpo/evmpo.ttl#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix http-meth: <http://www.w3.org/2011/http-methods#> .
# @prefix msm: <http://iserve.kmi.open.ac.uk/ns/msm#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix xs: <http://www.w3.org/2001/XMLSchema#> .
#
# skos:ConceptScheme a owl:Class ;
#     rdfs:subClassOf evmpo:information_content_entity .
#
# dome-core: a owl:Ontology ;
#     dcterms:contributor "Adham Hashibon"^^xs:string,
#         "Amit Bhave"^^xs:string,
#         "Bijan Yadollahi"^^xs:string,
#         "Bjorn Tore Lovfall"^^xs:string,
#         "Emanuele Ghedini"^^xs:string,
#         "Gerhard Goldbeck"^^xs:string,
#         "Ilian Todorov"^^xs:string,
#         "Jesper Friis"^^xs:string,
#         "Kok Foong Lee"^^xs:string,
#         "Konstantinos Sipsas"^^xs:string,
#         "Kristine Wiik"^^xs:string,
#         "Martin Thomas Horsch"^^xs:string,
#         "Martin Uhrin"^^xs:string,
#         "Michael Seaton"^^xs:string,
#         "Mike Wang"^^xs:string,
#         "Noel Vizcaino"^^xs:string,
#         "Stijn Donders"^^xs:string,
#         "Treesa Joseph"^^xs:string,
#         "Vasily Bunakov"^^xs:string ;
#     dcterms:creator "Silvia Chiacchiera"^^xs:string ;
#     dcterms:license """DOME 4.0 Ecosystem ontology is provided under the CC-BY-4.0 license\r
# (https://creativecommons.org/licenses/by/4.0/legalcode)"""^^xs:string ;
#     dcterms:modified "2022-11-25"^^xs:string ;
#     dcterms:title "DOME 4.0 Ecosystem ontology"^^xs:string ;
#     rdfs:comment """The authors acknowledge funding from the European Union's Horizon 2020 research \r
# and innovation programme under grant agreement no. 953163, Digital Open Marketplace Ecosystem 4.0 \r
# (DOME 4.0)."""^^xs:string ;
#     owl:versionInfo "version 1.0.0"^^xs:string .
#
# dome-core:DATA_ON_DEMAND_PROVIDER a dome-core:data_on_demand_provider .
#
# dome-core:conforms_to a owl:ObjectProperty ;
#     rdfs:comment "Points to a (widely-used) API specification the platform conforms to"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:standard_api_specification ;
#     rdfs:subPropertyOf dcterms:conformsTo .
#
# dome-core:dcat_catalogue rdfs:label "DCAT catalogue"^^xs:string ;
#     rdfs:comment "Catalog of datasets and data-services, as defined in DCAT-2 (Data Catalog Vocabulary)"^^xs:string ;
#     rdfs:subClassOf dome-core:dataset,
#         dome-core:product_catalogue ;
#     owl:equivalentClass dcat:Catalog .
#
# dome-core:has_cost_per_unit a owl:DatatypeProperty ;
#     rdfs:comment "Property that points to the cost (in euros) of a pricing unit"^^xs:string ;
#     rdfs:domain dome-core:offering_by_usage ;
#     rdfs:range xs:decimal .
#
# dome-core:has_data_schema a owl:ObjectProperty ;
#     rdfs:comment "Points to the data schema of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:data_schema .
#
# dome-core:has_input_part a owl:ObjectProperty ;
#     rdfs:comment "Points to a part of the input of an operation (inspired by Minimal Service model, MSM)."^^xs:string ;
#     rdfs:domain dome-core:operation ;
#     rdfs:range dome-core:message_part .
#
# dome-core:has_number_of_free_units a owl:DatatypeProperty ;
#     rdfs:comment "Property that points to the number of free units in the offering"^^xs:string ;
#     rdfs:domain dome-core:offering_by_usage ;
#     rdfs:range xs:integer .
#
# dome-core:has_offering_constraints a owl:DatatypeProperty ;
#     rdfs:comment """Property that points to the eventual constraints of the offering\r
# (e.g., minimum duration or caps on usage)"""^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range xs:string .
#
# dome-core:has_offering_description a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Property that points to the description of the offering/bundle"^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range xs:string .
#
# dome-core:has_offering_name a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Property that points to the name of the offering/bundle"^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range xs:string .
#
# dome-core:has_offering_number_of_free_periods a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Property that points to the number of free (trial) periods"^^xs:string ;
#     rdfs:domain dome-core:offering_subscription ;
#     rdfs:range xs:decimal .
#
# dome-core:has_offering_one_off_cost a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Property that points to the eventual one-off initial cost (in Euros) of the offering/bundle"^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range xs:decimal .
#
# dome-core:has_offering_periodic_cost a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Property that points to the periodic cost (in Euros) of the offering/bundle"^^xs:string ;
#     rdfs:domain dome-core:offering_subscription ;
#     rdfs:range xs:decimal .
#
# dome-core:has_offering_periodicity a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment """Property that points to the periodicity of the offering/bundle.\r
# For example, the value could be: one month, four weeks, one year, etc."""^^xs:string ;
#     rdfs:domain dome-core:offering_subscription ;
#     rdfs:range xs:string .
#
# dome-core:has_offering_pricing_unit a owl:DatatypeProperty ;
#     rdfs:comment """Examples of pricing units are: hours of usage of a service, number of downloaded datasets,\r
# number of successful queries, size of downloaded data in Mb, etc"""^^xs:string,
#         "Property that points to the pricing unit of the offering/bundle by usage"^^xs:string ;
#     rdfs:domain dome-core:offering_by_usage ;
#     rdfs:range xs:string .
#
# dome-core:has_output_part a owl:ObjectProperty ;
#     rdfs:comment "Points to a part of the output of an operation (inspired by Minimal Service model, MSM)."^^xs:string ;
#     rdfs:domain dome-core:operation ;
#     rdfs:range dome-core:message_part .
#
# dome-core:has_platform_description a owl:DatatypeProperty ;
#     rdfs:comment "Points to the platform (text) description"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:string .
#
# dome-core:has_platform_machine_query_information a owl:DatatypeProperty ;
#     rdfs:comment "Gives information (text) on how machine query strings are formed"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:string .
#
# dome-core:has_platform_maintainer a owl:ObjectProperty ;
#     rdfs:comment "Points to a maintainer of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:platform_maintainer ;
#     rdfs:subPropertyOf dome-core:has_platform_agent .
#
# dome-core:has_platform_name a owl:DatatypeProperty ;
#     rdfs:comment "Points to the platform name"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:string .
#
# dome-core:has_platform_owner a owl:ObjectProperty ;
#     rdfs:comment "Points to an owner of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:platform_owner ;
#     rdfs:subPropertyOf dome-core:has_platform_agent .
#
# dome-core:has_platform_topic a owl:ObjectProperty ;
#     rdfs:comment "Points to a topic/theme of the (data and services on the) platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:topic .
#
# dome-core:has_platform_url_api_documentation a owl:DatatypeProperty ;
#     rdfs:comment "Points to the URL of the documentation for the platform API"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:anyURI ;
#     rdfs:subPropertyOf dome-core:has_platform_url .
#
# dome-core:has_platform_url_home a owl:DatatypeProperty ;
#     rdfs:comment "Points to the URL of the platform homepage"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:anyURI ;
#     rdfs:subPropertyOf foaf:homepage,
#         dome-core:has_platform_url .
#
# dome-core:has_platform_url_query_api a owl:DatatypeProperty ;
#     rdfs:comment "Points to the URL of the platform query API"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:anyURI ;
#     rdfs:subPropertyOf dome-core:has_platform_url .
#
# dome-core:has_platform_user a owl:ObjectProperty ;
#     rdfs:comment "Points to a user of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:platform_user ;
#     rdfs:subPropertyOf dome-core:has_platform_agent .
#
# dome-core:has_schema_mapping a owl:ObjectProperty ;
#     rdfs:comment "Points to the (possibly partial) mapping of a data schema to DOME 4.0 or EMMO concepts"^^xs:string ;
#     rdfs:domain dome-core:data_schema ;
#     rdfs:range dome-core:schema_mapping .
#
# dome-core:has_service_type a owl:ObjectProperty ;
#     rdfs:comment "For example: View, Download, etc. "^^xs:string,
#         "In DCAT, dct:type is used for this purpose. "^^xs:string,
#         "Points to the service type (cf. 'action')"^^xs:string ;
#     rdfs:domain dome-core:service ;
#     rdfs:range dome-core:action ;
#     owl:propertyChainAxiom ( dome-core:has_operation dome-core:has_operation_type ) .
#
# dome-core:has_some_free_product a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Boolean property on whether the platform offers some free products or not"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:boolean .
#
# dome-core:has_version_identifier a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Identifies the version of an entity (e.g., platform, data schema, or another resource)"^^xs:string,
#         "It can be a number or a suffix in the name"^^xs:string ;
#     rdfs:domain [ a owl:Class ;
#             owl:unionOf ( evmpo:infrastructure evmpo:information_content_entity ) ] ;
#     rdfs:range xs:string .
#
# dome-core:includes_product a owl:ObjectProperty ;
#     rdfs:comment "Points to a product that is included in the offering"^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range dome-core:product ;
#     owl:propertyChainAxiom ( dome-core:includes_platform dome-core:offers_product ) .
#
# dome-core:is_sso_compatible a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Boolean property on whether the platform is compatible with DOME 4.0 SSO (Single Sign On)"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:boolean .
#
# dome-core:is_unlimited a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment """Property that specifies whether the flat offering is unlimited or not.\r
# See also the related property to specify offering constraints."""^^xs:string ;
#     rdfs:domain dome-core:offering_flat ;
#     rdfs:range xs:boolean .
#
# dome-core:offers_product_type a owl:ObjectProperty ;
#     rdfs:comment "Points to a product type that is offered on the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:product_type ;
#     rdfs:subPropertyOf dome-core:offers ;
#     owl:propertyChainAxiom ( dome-core:offers_product dome-core:has_product_type ) .
#
# dome-core:supports_pagination a owl:DatatypeProperty,
#         owl:FunctionalProperty ;
#     rdfs:comment "Boolean property that states whether a service supports pagination or not"^^xs:string ;
#     rdfs:domain dome-core:service ;
#     rdfs:range xs:boolean .
#
# dome-core:uses_english_spelling a owl:ObjectProperty ;
#     rdfs:comment "Points to the spelling of English (UK/GB or US) that is used by a service"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:english_spelling .
#
# dome-core:uses_input_file_format a owl:ObjectProperty ;
#     rdfs:comment "Points to a file format that can be consumed (I) by the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:file_format ;
#     rdfs:subPropertyOf dome-core:uses_file_format .
#
# dome-core:uses_output_file_format a owl:ObjectProperty ;
#     rdfs:comment "Points to a file format that is offered (O) by the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:file_format ;
#     rdfs:subPropertyOf dome-core:uses_file_format .
#
# dome-core:uses_standard_identifier a owl:ObjectProperty ;
#     rdfs:comment "Points to a standard identifier that is recognized by the platform API"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:standard_identifier .
#
# dome-core:CONSUMER a dome-core:consumer .
#
# dome-core:DATA_PROVIDER a dome-core:data_provider .
#
# dome-core:INTERACTIVE_APP_PROVIDER a dome-core:interactive_app_provider .
#
# dome-core:api_specification a owl:Class ;
#     rdfs:label "API specification"^^xs:string ;
#     rdfs:comment "Specification of an API"^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity .
#
# dome-core:connect_type_service a owl:Class ;
#     rdfs:comment "A service having an operation using the CONNECT (HTTP) method"^^xs:string ;
#     rdfs:subClassOf dome-core:service ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:hasValue http-meth:CONNECT ;
#             owl:onProperty dome-core:has_oper_has_meth ] .
#
# dome-core:consumer a owl:Class ;
#     rdfs:label "Consumer"^^xs:string ;
#     rdfs:comment "A platform that consumes data (a data sink)"^^xs:string ;
#     rdfs:subClassOf dome-core:platform_type .
#
# dome-core:data_on_demand_provider a owl:Class ;
#     rdfs:label "Data-on-demand provider"^^xs:string ;
#     rdfs:comment "Provider of data on demand (i.e, upon sending a request, one gets a receipt, then the data - possibly after some time)"^^xs:string ;
#     rdfs:subClassOf dome-core:provider .
#
# dome-core:data_provider a owl:Class ;
#     rdfs:label "Data provider"^^xs:string ;
#     rdfs:comment "Provider of data (that exists already, is stored and can be obtained immediately upon request)"^^xs:string ;
#     rdfs:subClassOf dome-core:provider .
#
# dome-core:data_service rdfs:label "Data service"^^xs:string ;
#     rdfs:comment "Data service, as defined in DCAT-2 (Data Catalog Vocabulary)"^^xs:string ;
#     rdfs:subClassOf dome-core:resource,
#         dome-core:service ;
#     owl:equivalentClass dcat:DataService .
#
# dome-core:english_spelling a owl:Class ;
#     rdfs:label "Spelling variant of English"^^xs:string ;
#     rdfs:subClassOf evmpo:annotation ;
#     owl:oneOf ( dome-core:UK_ENGLISH dome-core:US_ENGLISH ) .
#
# dome-core:get_type_service a owl:Class ;
#     rdfs:comment "A service having an operation using the GET (HTTP) method"^^xs:string ;
#     rdfs:subClassOf dome-core:service ;
#     owl:equivalentClass [ a owl:Restriction ;
#             owl:hasValue http-meth:GET ;
#             owl:onProperty dome-core:has_oper_has_meth ] .
#
# dome-core:has_entry_for a owl:ObjectProperty ;
#     rdfs:comment "Points to a product for which the catalogue has an entry."^^xs:string ;
#     rdfs:domain dome-core:product_catalogue ;
#     rdfs:range dome-core:product .
#
# dome-core:has_http_method a owl:ObjectProperty ;
#     rdfs:comment "Points to the HTTP method used in the operation."^^xs:string ;
#     rdfs:domain dome-core:operation ;
#     rdfs:range dome-core:http_method .
#
# dome-core:has_operation_type a owl:ObjectProperty ;
#     rdfs:comment "Can be used when a service is split into operations addressing individual actions"^^xs:string,
#         "For example: View, Download, etc. "^^xs:string,
#         "Points to the operation type (cf. 'action')"^^xs:string ;
#     rdfs:domain dome-core:operation ;
#     rdfs:range dome-core:action .
#
# dome-core:has_product_catalogue a owl:ObjectProperty ;
#     rdfs:comment "Points to the product catalogue of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:product_catalogue .
#
# dome-core:has_product_type a owl:ObjectProperty ;
#     rdfs:comment "Points to the product type (a tag) of a product"^^xs:string ;
#     rdfs:domain dome-core:product ;
#     rdfs:range dome-core:product_type .
#
# dome-core:includes_platform a owl:ObjectProperty ;
#     rdfs:comment """Points to a platform that is included in the offering.\r
# I.e., all the products it offers are included in the offering."""^^xs:string ;
#     rdfs:domain dome-core:offering ;
#     rdfs:range dome-core:platform .
#
# dome-core:interactive_app_provider a owl:Class ;
#     rdfs:label "Interactive-application provider"^^xs:string ;
#     rdfs:comment "Provider of interactive application (i.e., one logs in and can perform actions)"^^xs:string ;
#     rdfs:subClassOf dome-core:provider .
#
# dome-core:offering_one_off_sale a owl:Class ;
#     rdfs:label "Offering one-off sale"^^xs:string ;
#     rdfs:comment "For example, a single dataset or using a service once."^^xs:string ;
#     rdfs:subClassOf dome-core:offering .
#
# dome-core:platform_maintainer a owl:Class ;
#     rdfs:label "Platform maintainer"^^xs:string ;
#     rdfs:comment "Can be used as role in KeyCloak"^^xs:string ;
#     rdfs:subClassOf dome-core:agent .
#
# dome-core:platform_owner a owl:Class ;
#     rdfs:label "Platform owner"^^xs:string ;
#     rdfs:comment "Can be used as role in KeyCloak"^^xs:string ;
#     rdfs:subClassOf dome-core:agent .
#
# dome-core:platform_user a owl:Class ;
#     rdfs:label "Platform user"^^xs:string ;
#     rdfs:comment "Can be used as role in KeyCloak"^^xs:string ;
#     rdfs:subClassOf dome-core:agent .
#
# dome-core:post_or_put_type_service a owl:Class ;
#     rdfs:comment "A service having an operation using the POST or PUT (HTTP) methods"^^xs:string ;
#     rdfs:subClassOf dome-core:service ;
#     owl:unionOf ( [ a owl:Restriction ;
#                 owl:hasValue http-meth:POST ;
#                 owl:onProperty dome-core:has_oper_has_meth ] [ a owl:Restriction ;
#                 owl:hasValue http-meth:PUT ;
#                 owl:onProperty dome-core:has_oper_has_meth ] ) .
#
# dome-core:schema_mapping a owl:Class ;
#     rdfs:label "Schema mapping"^^xs:string ;
#     rdfs:comment "A (possibly partial) mapping of a data schema to DOME 4.0 and/or EMMO concepts"^^xs:string,
#         "It can inlcude alignment-type statements as well."^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity .
#
# dome-core:standard_api_specification a owl:Class ;
#     rdfs:label "Standard API specification"^^xs:string ;
#     rdfs:comment "An API specification that is followed by multiple platforms, e.g., OPTIMADE or IDS."^^xs:string ;
#     rdfs:subClassOf dome-core:api_specification .
#
# dome-core:standard_identifier a owl:Class ;
#     rdfs:label "Standard identifier"^^xs:string ;
#     rdfs:comment "A string widely used to identify an entity in the materials and manufacturing domain"^^xs:string ;
#     rdfs:subClassOf evmpo:annotation .
#
# dome-core:topic a owl:Class ;
#     rdfs:label "Topic"^^xs:string ;
#     rdfs:comment "Topic, theme, domain - to be taken from a widely used list (such as DFG list of disciplines or EuroSciVoc)."^^xs:string ;
#     rdfs:subClassOf evmpo:annotation .
#
# dome-core:action a owl:Class ;
#     rdfs:label "Action"^^xs:string ;
#     rdfs:subClassOf evmpo:process .
#
# dome-core:data_schema a owl:Class ;
#     rdfs:label "Data schema"^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity .
#
# dome-core:dataset rdfs:label "Dataset"^^xs:string ;
#     rdfs:comment "Dataset, as defined in DCAT-2 (Data Catalog Vocabulary)"^^xs:string ;
#     rdfs:subClassOf dome-core:resource,
#         evmpo:information_content_entity ;
#     owl:equivalentClass dcat:Dataset .
#
# dome-core:has_operation a owl:ObjectProperty ;
#     rdfs:comment "Points to an operation of a web-service (cf. Minimal Service model, MSM)."^^xs:string ;
#     rdfs:domain dome-core:service ;
#     rdfs:range dome-core:operation ;
#     owl:equivalentProperty msm:hasOperation .
#
# dome-core:http_method a owl:Class ;
#     rdfs:label "HTTP method"^^xs:string ;
#     rdfs:comment "We duplicate here for convenience the list of all HTTP verbs (cf. W3C RDF vocabulary for HTTP)."^^xs:string ;
#     rdfs:subClassOf evmpo:annotation ;
#     owl:oneOf ( http-meth:CONNECT http-meth:DELETE http-meth:GET http-meth:HEAD http-meth:OPTIONS http-meth:PATCH http-meth:POST http-meth:PUT http-meth:TRACE ) .
#
# dome-core:message_part a owl:Class ;
#     rdfs:label "Message part"^^xs:string ;
#     rdfs:comment "Cf. the Minimal Service model, MSM."^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity ;
#     owl:equivalentClass msm:MessagePart .
#
# dome-core:offering_flat a owl:Class ;
#     rdfs:label "Flat offering"^^xs:string ;
#     rdfs:comment "An offering whose cost does not depend on usage"^^xs:string ;
#     rdfs:subClassOf dome-core:offering .
#
# dome-core:offers a owl:ObjectProperty ;
#     rdfs:comment "Points to a product or a product type that is offered on the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range [ a owl:Class ;
#             owl:unionOf ( dome-core:product_type dome-core:product ) ] .
#
# dome-core:offers_product a owl:ObjectProperty ;
#     rdfs:comment "Points to a (concrete, individual) product that is offered on the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:product ;
#     rdfs:subPropertyOf dome-core:offers ;
#     owl:propertyChainAxiom ( dome-core:has_product_catalogue dome-core:has_entry_for ) .
#
# dome-core:resource rdfs:label "Resource"^^xs:string ;
#     rdfs:comment """Currently defined as union of dataset and data_service. As per DCAT recommendations,\r
# other sub-classes can be added, but then they should be explicitly defined."""^^xs:string,
#         "Resource, as defined in DCAT-2 (Data Catalog Vocabulary)"^^xs:string ;
#     rdfs:subClassOf dome-core:product ;
#     owl:equivalentClass dcat:Resource ;
#     owl:unionOf ( dome-core:dataset dome-core:data_service ) .
#
# dome-core:uses_file_format a owl:ObjectProperty ;
#     rdfs:comment "Points to a file format that is offered or can be consumed (I/O) on the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:file_format .
#
# dome-core:file_format a owl:Class ;
#     rdfs:label "File format"^^xs:string ;
#     rdfs:subClassOf evmpo:annotation .
#
# dome-core:has_platform_agent a owl:ObjectProperty ;
#     rdfs:comment "Points to an agent of (i.e., somebody that can act on) the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:agent .
#
# dome-core:has_platform_type a owl:ObjectProperty ;
#     rdfs:comment "Points to the platform type"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:platform_type .
#
# dome-core:has_platform_url a owl:DatatypeProperty ;
#     rdfs:comment "Points to a URL that is relevant for the platform (e.g., homepage, querying, etc)"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range xs:anyURI .
#
# dome-core:has_service a owl:ObjectProperty ;
#     rdfs:comment "Points to a (web) service of the platform"^^xs:string ;
#     rdfs:domain dome-core:platform ;
#     rdfs:range dome-core:service .
#
# dome-core:platform_type a owl:Class ;
#     rdfs:label "Platform type"^^xs:string ;
#     rdfs:comment "A platform can have multiple types, they are not disjoint from each other."^^xs:string,
#         """Classification of platforms used by DOME 4.0, from the perspective \r
#   	       of data flow and connectors. """^^xs:string ;
#     rdfs:subClassOf evmpo:annotation .
#
# dome-core:product_catalogue a owl:Class ;
#     rdfs:label "Product catalogue"^^xs:string ;
#     rdfs:comment "Could be given as a DCAT catalogue or not"^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity .
#
# dome-core:product_type a owl:Class ;
#     rdfs:label "Product type"^^xs:string ;
#     rdfs:comment "A tag, used to categorize products"^^xs:string ;
#     rdfs:subClassOf evmpo:annotation .
#
# dome-core:provider a owl:Class ;
#     rdfs:label "Provider"^^xs:string ;
#     rdfs:comment "A platform that provides data and/or applications"^^xs:string ;
#     rdfs:subClassOf dome-core:platform_type .
#
# dome-core:agent a owl:Class ;
#     rdfs:label "Agent"^^xs:string ;
#     rdfs:comment "An agent in the EMVPO sense - somebody that can act on the marketplace ecosystem."^^xs:string ;
#     rdfs:subClassOf evmpo:agent .
#
# dome-core:has_oper_has_meth a owl:ObjectProperty ;
#     rdfs:comment "Points to an HTTP method used by an operation of the given service"^^xs:string ;
#     rdfs:domain dome-core:service ;
#     rdfs:range dome-core:http_method ;
#     owl:propertyChainAxiom ( dome-core:has_operation dome-core:has_http_method ) .
#
# dome-core:offering_by_usage a owl:Class ;
#     rdfs:label "Offering by usage"^^xs:string ;
#     rdfs:comment "An offering whose cost depends on usage"^^xs:string ;
#     rdfs:subClassOf dome-core:offering .
#
# dome-core:offering_subscription a owl:Class ;
#     rdfs:label "Offering subscription"^^xs:string ;
#     rdfs:comment "An offering providing access to products in a continued (possibly periodic) or repeated way."^^xs:string ;
#     rdfs:subClassOf dome-core:offering ;
#     owl:disjointUnionOf ( dome-core:offering_by_usage dome-core:offering_flat ) .
#
# dome-core:operation a owl:Class ;
#     rdfs:label "Operation"^^xs:string ;
#     rdfs:comment "Cf. the Minimal Service model, MSM."^^xs:string,
#         "Part of a web service, for example a block that carries out a function"^^xs:string ;
#     rdfs:subClassOf evmpo:infrastructure ;
#     owl:equivalentClass msm:Operation .
#
# dome-core:product a owl:Class ;
#     rdfs:label "Product"^^xs:string ;
#     rdfs:comment "A product in the EMVPO sense - someting that can be traded on the marketplace ecosystem"^^xs:string ;
#     rdfs:subClassOf evmpo:product .
#
# dome-core:service a owl:Class ;
#     rdfs:label "(Web) Service"^^xs:string ;
#     rdfs:comment "Cf. the Minimal Service model, MSM."^^xs:string ;
#     rdfs:subClassOf evmpo:infrastructure ;
#     owl:equivalentClass msm:Service .
#
# dome-core:offering a owl:Class ;
#     rdfs:label "Offering"^^xs:string ;
#     rdfs:comment "Can be defined at the platform or product level, can involve one or multiple products and platforms."^^xs:string,
#         "Offering/bundle of data and/or data services on DOME 4.0"^^xs:string,
#         "This and sub-classes are not directly related to, but inspired by: PaasPort, GoodRelations and IDS concepts."^^xs:string ;
#     rdfs:subClassOf evmpo:information_content_entity ;
#     owl:disjointUnionOf ( dome-core:offering_subscription dome-core:offering_one_off_sale ) ;
#     skos:altLabel "Bundle"^^xs:string .
#
# dome-core:platform a owl:Class ;
#     rdfs:label "Platform"^^xs:string ;
#     rdfs:comment "A web-based platform offering products, data and data services"^^xs:string,
#         """From Merriam-Webster: (in computing) "an application or website that\r
#   	       serves as a base from which a service is provided" [“Platform.” Merriam-Webster.com \r
#   	       Dictionary, Merriam-Webster, https://www.merriam-webster.com/dictionary/platform. \r
# 	       Accessed 13 Sep. 2022.]"""^^xs:string ;
#     rdfs:subClassOf evmpo:infrastructure .
#
# [] a owl:Restriction ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:hasValue dome-core:CONSUMER ;
#             owl:onProperty dome-core:has_platform_type ] ;
#     owl:onProperty dome-core:has_service ;
#     owl:someValuesFrom dome-core:post_or_put_type_service .
#
# [] a owl:Restriction ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:hasValue dome-core:DATA_PROVIDER ;
#             owl:onProperty dome-core:has_platform_type ] ;
#     owl:onProperty dome-core:has_service ;
#     owl:someValuesFrom dome-core:get_type_service .
#
# [] a owl:Restriction ;
#     rdfs:subClassOf [ a owl:Restriction ;
#             owl:hasValue dome-core:INTERACTIVE_APP_PROVIDER ;
#             owl:onProperty dome-core:has_platform_type ] ;
#     owl:onProperty dome-core:has_service ;
#     owl:someValuesFrom dome-core:connect_type_service .

# %%
dome2=SimpleNamespace()
